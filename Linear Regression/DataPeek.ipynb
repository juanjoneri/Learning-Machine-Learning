# %% [markdown]
# # See what the data looks like and try to plot it in some way

# %% [markdown]
# ## Description by original src *Andrew Ng*
# > area_br_price.txt contains a training set of housing prices in Port-
# land, Oregon. The .rst column is the size of the house (in square feet), the
# second column is the number of bedrooms, and the third column is the price
# of the house.
#
# Does not really have too many data points, 47 to be exact :(

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
house_data = np.genfromtxt('./Datasets/area_br_price.txt', delimiter=',')

# %% [markdown]
# ### Import the data

# %%
# As usual import using np and reshape because, we want to join the data of the same type.
house_data = np.genfromtxt('./Datasets/area_br_price.txt', delimiter=',')
house_data = house_data.T
# move to other variables with better names
areas = house_data[0]
rooms = house_data[1]
prices = house_data[2]
# Show that indeed the data looks as expected
np.shape(house_data)
# Out:
# (3, 47)

# %%
# A really bad function that will only work if the names are set as such, but migh prove useful in this notebook
def houseInfo (i) :
    print("for example, house number {} has {} sqf and {} rooms => It costs ${}".format(i, areas[i], rooms[i], prices[i]))
    
houseInfo(3)
# Out:
# for example, house number 3 has 1416.0 sqf and 2.0 rooms => It costs $232000.0

# %%
""" 
plt.plot ( x , y , '[color][icon]' )
where [color] => b, r, g 
      [icon]  => o, s, --, ^
"""

plt.plot(areas, prices, 'go') #go looks apropiate for money
plt.xlabel('Area (sqf)')
plt.ylabel('Price (us$)')
plt.show()

# %%
plt.plot(prices, rooms, 'b^') # b^ for... blue triangles
plt.show()
